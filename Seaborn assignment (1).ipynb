# %%
#Que 1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
#Ans:
#5 plots from seaborn are 1.scatterplot,2.histogram,3.pairplot,4.jointplot,5.line plot
import seaborn as sns

# %%
data = sns.load_dataset('iris')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#Use of scatterplot
sns.scatterplot(x = data.sepal_length , y = data.sepal_width)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#Use of histogram
sns.displot(data['sepal_width'])

# %%
#Use of pairplot
sns.pairplot(data)

# %%
#Use of jointplot
sns.jointplot(x = data.sepal_length , y = data.petal_length)

# %%
#Use of pie plot
sns.lineplot(x = data.sepal_length , y = data.sepal_width)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
#Que 2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = "timepoint" and y = "signal" for different events and regions.
#Ans:
fmri = sns.load_dataset('fmri')

# %%
sns.lineplot(x = fmri.timepoint , y = fmri.signal)
# Out:
# <AxesSubplot: xlabel='timepoint', ylabel='signal'>

# %%
#Que 3: Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 'pclass', y = 'age' and y = 'fare'.
#Ans:
titanic = sns.load_dataset('titanic')

# %%
sns.boxplot(x = titanic.pclass , y = titanic.age)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x = titanic.pclass , y = titanic.fare)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
#Que 4: Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue parameter for the 'cut' column of the diamonds dataset.
#Ans:
diamond = sns.load_dataset('diamonds')

# %%
sns.histplot(data = diamond , x = 'price' , hue = 'cut')
# Out:
# <AxesSubplot: xlabel='price', ylabel='Count'>

# %%
#Que 5: Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column of the iris dataset.
#Ans:
iris = sns.load_dataset('iris')

# %%
sns.pairplot(iris ,hue = 'species')

# %%
#Que 6: Use the "flights" dataset from seaborn to plot a heatmap.
#Ans:
flights = sns.load_dataset("flights")
flights1 = flights.pivot("month", "year", "passengers")
sns.heatmap(flights1)
# Out:
# /tmp/ipykernel_2153/2384523625.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights1 = flights.pivot("month", "year", "passengers")
# <AxesSubplot: xlabel='year', ylabel='month'>
